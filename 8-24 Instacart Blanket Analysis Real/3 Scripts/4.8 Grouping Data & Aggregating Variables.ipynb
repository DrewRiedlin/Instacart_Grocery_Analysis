# %% [markdown]
# # 4.8 Grouping Data & Aggregating Variables

# %%
#Import pandas numpy and os
import pandas as pd
import numpy as np
import os

# %%
#Import merged dataframe df_ords_prods_prior_merged as ords_prods_merge
ords_prods_merge = pd.read_pickle('/Users/ariedlin/Desktop/Career Foundry Assignments/8-24 Instacart Blanket Analysis Real/2 Data/2 Prepared Data/df_ords_prods_prior_merged')

# %% [markdown]
# # Grouping Data

# %%
#Create a subset of data containging only the first 1,000,000 rows
df = ords_prods_merge[:1000000]

# %%
#Check the head to make sure it worked
df.head()
# Out:
#    Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_dow  \
# 0             0   2539329        1    prior             1           2
# 1             0   2539329        1    prior             1           2
# 2             0   2539329        1    prior             1           2
# 3             0   2539329        1    prior             1           2
# 4             0   2539329        1    prior             1           2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    ...  Unnamed: 0_y                             product_name  aisle_id  \
# ...

# %%
#Check the shape of the sample dataframe to ensure 1,000,000 rows
df.shape
# Out:
# (1000000, 22)

# %% [markdown]
# # Grouping Data with pandas

# %%
#Use the groupby function to group the 'product_name' column
df.groupby('product_name')

# %% [markdown]
# # Performing a Single Aggregation

# %%
#Calculate the mean of the order_number and group by department_id
df.groupby('department_id').agg({'order_number': ['mean']})
# Out:
#               order_number
#                       mean
# department_id
# 1                14.800024
# 2                17.091743
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 20               17.138607
# 21               21.956893

# %%
#Aggregate the data using the mean() function
df.groupby('department_id')['order_number'].mean()
# Out:
# department_id
# 1     14.800024
# 2     17.091743
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 20    17.138607
# 21    21.956893
# Name: order_number, dtype: float64

# %% [markdown]
# # Performing Multiple Aggregations

# %%
#Calculate the mean, min, and max of the order_number and group by department_id
df.groupby('department_id').agg({'order_number': ['mean', 'min', 'max']})
# Out:
#               order_number
#                       mean min max
# department_id
# 1                14.800024   1  99
# 2                17.091743   1  98
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 20               17.138607   1  99
# 21               21.956893   1  97

# %% [markdown]
# # Aggregating Data with transform()

# %%
#Create new column 'max_order' to find max for 'order_number' and group by 'user_id'
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)
# Out:
# /var/folders/zg/lgqcn1jn6md3p8399q9rqkwm0000gn/T/ipykernel_9744/1979927799.py:2: FutureWarning: The provided callable <function max at 0x10a091da0> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_number'].transform(np.max)

# %%
#Check head() to ensure it worked
ords_prods_merge.head(15)
# Out:
#     Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_dow  \
# 0              0   2539329        1    prior             1           2
# 1              0   2539329        1    prior             1           2
# 2              0   2539329        1    prior             1           2
# 3              0   2539329        1    prior             1           2
# 4              0   2539329        1    prior             1           2
# 5              1   2398795        1    prior             2           3
# 6              1   2398795        1    prior             2           3
# 7              1   2398795        1    prior             2           3
# 8              1   2398795        1    prior             2           3
# 9              1   2398795        1    prior             2           3
# 10             1   2398795        1    prior             2           3
# 11             2    473747        1    prior             3           3
# ...

# %%
#Check the head(100) to check the max_order column for accuracy
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_dow  \
# 0              0   2539329        1    prior             1           2
# 1              0   2539329        1    prior             1           2
# 2              0   2539329        1    prior             1           2
# 3              0   2539329        1    prior             1           2
# 4              0   2539329        1    prior             1           2
# ..           ...       ...      ...      ...           ...         ...
# 95            14    738281        2    prior             4           2
# 96            15   1673511        2    prior             5           3
# 97            15   1673511        2    prior             5           3
# 98            15   1673511        2    prior             5           3
# 99            15   1673511        2    prior             5           3
#
#     order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# ...

# %%
#Tell pandas to turn off the limit for how many rows can be displayed in Jupyter
pd.options.display.max_rows = None

# %%
#Print head() again to check for correct output
ords_prods_merge.head(100)
# Out:
#     Unnamed: 0_x  order_id  user_id eval_set  order_number  orders_dow  \
# 0              0   2539329        1    prior             1           2
# 1              0   2539329        1    prior             1           2
# 2              0   2539329        1    prior             1           2
# 3              0   2539329        1    prior             1           2
# 4              0   2539329        1    prior             1           2
# 5              1   2398795        1    prior             2           3
# 6              1   2398795        1    prior             2           3
# 7              1   2398795        1    prior             2           3
# 8              1   2398795        1    prior             2           3
# 9              1   2398795        1    prior             2           3
# 10             1   2398795        1    prior             2           3
# 11             2    473747        1    prior             3           3
# ...

# %% [markdown]
# # Deriving Columns with loc()

# %%
#Assign 'loyalty' flags using loc()
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
#Check the value_counts of new 'loyalty_flag' column
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
#Check the head() to ensure accuracy
ords_prods_merge[['user_id', 'loyalty_flag', 'order_number']].head(60)
# Out:
#     user_id      loyalty_flag  order_number
# 0         1      New customer             1
# 1         1      New customer             1
# 2         1      New customer             1
# 3         1      New customer             1
# 4         1      New customer             1
# 5         1      New customer             2
# 6         1      New customer             2
# 7         1      New customer             2
# 8         1      New customer             2
# 9         1      New customer             2
# 10        1      New customer             2
# 11        1      New customer             3
# 12        1      New customer             3
# 13        1      New customer             3
# 14        1      New customer             3
# 15        1      New customer             3
# 16        1      New customer             4
# 17        1      New customer             4
# 18        1      New customer             4
# 19        1      New customer             4
# ...

# %%
#Export ords_prods_merge as a pickle
ords_prods_merge.to_pickle('/Users/ariedlin/Desktop/Career Foundry Assignments/8-24 Instacart Blanket Analysis Real/2 Data/2 Prepared Data/ords_prods_merge')
